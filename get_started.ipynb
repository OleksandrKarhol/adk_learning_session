# %% [markdown]
# 1. Install the library

# %%
# !pip3 install google-adk

# %% [markdown]
# 2. Create an agent project

# %%
# !adk create my_agent

# %% [markdown]
# 3. Export the api key

# %%
# !export GEMINI_API_KEY=<your_api_key>

# %% [markdown]
# 4. Install MCP toolset and run MCP locally

# %% [markdown]
# 1. curl -O https://storage.googleapis.com/genai-toolbox/v0.7.0/darwin/arm64/toolbox
# 2. chmod +x toolbox
# 3. ./toolbox --version
# 4. export BIGQUERY_PROJECT=ideals-product-analytics
# 5. gcloud auth application-default login
# 6. ./toolbox --prebuilt bigquery
# 7. Create new terminal
# 8. npx @modelcontextprotocol/inspector
# 9. Type y when it asks to install the inspector package.
# 10. It should show the following when the MCP Inspector is up and running: 🔍 MCP Inspector is up and running at http://127.0.0.1:5173 🚀
# 11. Open the above link in your browser.
# 12. For Transport Type, select SSE.
# 13. For URL, type in http://127.0.0.1:5000/mcp/sse.
# 14. Click Connect.
